# %% [markdown]
# **Data Extraction**
#
# Executed in ```data_extraction.py```, the attributes of each sample patient is taken from the ```heart.csv``` and placed in a NumPy array. A NumPy array allows for complex manipulation and editing of multideimnesional arrays (in our case, a 3D array).

# %%
# !python data_extraction.py
# Out:
# [EXTRACT] Row 0 finished
# [EXTRACT] Row 1 finished
# [EXTRACT] Row 2 finished
# [EXTRACT] Row 3 finished
# [EXTRACT] Row 4 finished
# [EXTRACT] Row 5 finished
# [EXTRACT] Row 6 finished
# [EXTRACT] Row 7 finished
# [EXTRACT] Row 8 finished
# [EXTRACT] Row 9 finished
# [EXTRACT] Row 10 finished
# [EXTRACT] Row 11 finished
# [EXTRACT] Row 12 finished
# [EXTRACT] Row 13 finished
# [EXTRACT] Row 14 finished
# [EXTRACT] Row 15 finished
# [EXTRACT] Row 16 finished
# [EXTRACT] Row 17 finished
# [EXTRACT] Row 18 finished
# [EXTRACT] Row 19 finished
# [EXTRACT] Row 20 finished
# [EXTRACT] Row 21 finished
# [EXTRACT] Row 22 finished
# [EXTRACT] Row 23 finished
# [EXTRACT] Row 24 finished
# [EXTRACT] Row 25 finished
# [EXTRACT] Row 26 finished
# [EXTRACT] Row 27 finished
# [EXTRACT] Row 28 finished
# [EXTRACT] Row 29 finished
# [EXTRACT] Row 30 finished
# [EXTRACT] Row 31 finished
# [EXTRACT] Row 32 finished
# [EXTRACT] Row 33 finished
# [EXTRACT] Row 34 finished
# [EXTRACT] Row 35 finished
# [EXTRACT] Row 36 finished
# [EXTRACT] Row 37 finished
# [EXTRACT] Row 38 finished
# [EXTRACT] Row 39 finished
# [EXTRACT] Row 40 finished
# [EXTRACT] Row 41 finished
# [EXTRACT] Row 42 finished
# [EXTRACT] Row 43 finished
# [EXTRACT] Row 44 finished
# [EXTRACT] Row 45 finished
# [EXTRACT] Row 46 finished
# [EXTRACT] Row 47 finished
# [EXTRACT] Row 48 finished
# [EXTRACT] Row 49 finished
# [EXTRACT] Row 50 finished
# [EXTRACT] Row 51 finished
# [EXTRACT] Row 52 finished
# [EXTRACT] Row 53 finished
# [EXTRACT] Row 54 finished
# [EXTRACT] Row 55 finished
# [EXTRACT] Row 56 finished
# [EXTRACT] Row 57 finished
# [EXTRACT] Row 58 finished
# [EXTRACT] Row 59 finished
# [EXTRACT] Row 60 finished
# [EXTRACT] Row 61 finished
# [EXTRACT] Row 62 finished
# [EXTRACT] Row 63 finished
# [EXTRACT] Row 64 finished
# [EXTRACT] Row 65 finished
# [EXTRACT] Row 66 finished
# [EXTRACT] Row 67 finished
# [EXTRACT] Row 68 finished
# [EXTRACT] Row 69 finished
# [EXTRACT] Row 70 finished
# [EXTRACT] Row 71 finished
# [EXTRACT] Row 72 finished
# [EXTRACT] Row 73 finished
# [EXTRACT] Row 74 finished
# [EXTRACT] Row 75 finished
# [EXTRACT] Row 76 finished
# [EXTRACT] Row 77 finished
# [EXTRACT] Row 78 finished
# [EXTRACT] Row 79 finished
# [EXTRACT] Row 80 finished
# [EXTRACT] Row 81 finished
# [EXTRACT] Row 82 finished
# [EXTRACT] Row 83 finished
# [EXTRACT] Row 84 finished
# [EXTRACT] Row 85 finished
# [EXTRACT] Row 86 finished
# [EXTRACT] Row 87 finished
# [EXTRACT] Row 88 finished
# [EXTRACT] Row 89 finished
# [EXTRACT] Row 90 finished
# [EXTRACT] Row 91 finished
# [EXTRACT] Row 92 finished
# [EXTRACT] Row 93 finished
# [EXTRACT] Row 94 finished
# [EXTRACT] Row 95 finished
# [EXTRACT] Row 96 finished
# [EXTRACT] Row 97 finished
# [EXTRACT] Row 98 finished
# [EXTRACT] Row 99 finished
# [EXTRACT] Row 100 finished
# [EXTRACT] Row 101 finished
# [EXTRACT] Row 102 finished
# [EXTRACT] Row 103 finished
# [EXTRACT] Row 104 finished
# [EXTRACT] Row 105 finished
# [EXTRACT] Row 106 finished
# [EXTRACT] Row 107 finished
# [EXTRACT] Row 108 finished
# [EXTRACT] Row 109 finished
# [EXTRACT] Row 110 finished
# [EXTRACT] Row 111 finished
# [EXTRACT] Row 112 finished
# [EXTRACT] Row 113 finished
# [EXTRACT] Row 114 finished
# [EXTRACT] Row 115 finished
# [EXTRACT] Row 116 finished
# [EXTRACT] Row 117 finished
# [EXTRACT] Row 118 finished
# [EXTRACT] Row 119 finished
# [EXTRACT] Row 120 finished
# [EXTRACT] Row 121 finished
# [EXTRACT] Row 122 finished
# [EXTRACT] Row 123 finished
# [EXTRACT] Row 124 finished
# [EXTRACT] Row 125 finished
# [EXTRACT] Row 126 finished
# [EXTRACT] Row 127 finished
# [EXTRACT] Row 128 finished
# [EXTRACT] Row 129 finished
# [EXTRACT] Row 130 finished
# [EXTRACT] Row 131 finished
# [EXTRACT] Row 132 finished
# [EXTRACT] Row 133 finished
# [EXTRACT] Row 134 finished
# [EXTRACT] Row 135 finished
# [EXTRACT] Row 136 finished
# [EXTRACT] Row 137 finished
# [EXTRACT] Row 138 finished
# [EXTRACT] Row 139 finished
# [EXTRACT] Row 140 finished
# [EXTRACT] Row 141 finished
# [EXTRACT] Row 142 finished
# [EXTRACT] Row 143 finished
# [EXTRACT] Row 144 finished
# [EXTRACT] Row 145 finished
# [EXTRACT] Row 146 finished
# [EXTRACT] Row 147 finished
# [EXTRACT] Row 148 finished
# [EXTRACT] Row 149 finished
# [EXTRACT] Row 150 finished
# [EXTRACT] Row 151 finished
# [EXTRACT] Row 152 finished
# [EXTRACT] Row 153 finished
# [EXTRACT] Row 154 finished
# [EXTRACT] Row 155 finished
# [EXTRACT] Row 156 finished
# [EXTRACT] Row 157 finished
# [EXTRACT] Row 158 finished
# [EXTRACT] Row 159 finished
# [EXTRACT] Row 160 finished
# [EXTRACT] Row 161 finished
# [EXTRACT] Row 162 finished
# [EXTRACT] Row 163 finished
# [EXTRACT] Row 164 finished
# [EXTRACT] Row 165 finished
# [EXTRACT] Row 166 finished
# [EXTRACT] Row 167 finished
# [EXTRACT] Row 168 finished
# [EXTRACT] Row 169 finished
# [EXTRACT] Row 170 finished
# [EXTRACT] Row 171 finished
# [EXTRACT] Row 172 finished
# [EXTRACT] Row 173 finished
# [EXTRACT] Row 174 finished
# [EXTRACT] Row 175 finished
# [EXTRACT] Row 176 finished
# [EXTRACT] Row 177 finished
# [EXTRACT] Row 178 finished
# [EXTRACT] Row 179 finished
# [EXTRACT] Row 180 finished
# [EXTRACT] Row 181 finished
# [EXTRACT] Row 182 finished
# [EXTRACT] Row 183 finished
# [EXTRACT] Row 184 finished
# [EXTRACT] Row 185 finished
# [EXTRACT] Row 186 finished
# [EXTRACT] Row 187 finished
# [EXTRACT] Row 188 finished
# [EXTRACT] Row 189 finished
# [EXTRACT] Row 190 finished
# [EXTRACT] Row 191 finished
# [EXTRACT] Row 192 finished
# [EXTRACT] Row 193 finished
# [EXTRACT] Row 194 finished
# [EXTRACT] Row 195 finished
# [EXTRACT] Row 196 finished
# [EXTRACT] Row 197 finished
# [EXTRACT] Row 198 finished
# [EXTRACT] Row 199 finished
# [EXTRACT] Row 200 finished
# [EXTRACT] Row 201 finished
# [EXTRACT] Row 202 finished
# [EXTRACT] Row 203 finished
# [EXTRACT] Row 204 finished
# [EXTRACT] Row 205 finished
# [EXTRACT] Row 206 finished
# [EXTRACT] Row 207 finished
# [EXTRACT] Row 208 finished
# [EXTRACT] Row 209 finished
# [EXTRACT] Row 210 finished
# [EXTRACT] Row 211 finished
# [EXTRACT] Row 212 finished
# [EXTRACT] Row 213 finished
# [EXTRACT] Row 214 finished
# [EXTRACT] Row 215 finished
# [EXTRACT] Row 216 finished
# [EXTRACT] Row 217 finished
# [EXTRACT] Row 218 finished
# [EXTRACT] Row 219 finished
# [EXTRACT] Row 220 finished
# [EXTRACT] Row 221 finished
# [EXTRACT] Row 222 finished
# [EXTRACT] Row 223 finished
# [EXTRACT] Row 224 finished
# [EXTRACT] Row 225 finished
# [EXTRACT] Row 226 finished
# [EXTRACT] Row 227 finished
# [EXTRACT] Row 228 finished
# [EXTRACT] Row 229 finished
# [EXTRACT] Row 230 finished
# [EXTRACT] Row 231 finished
# [EXTRACT] Row 232 finished
# [EXTRACT] Row 233 finished
# [EXTRACT] Row 234 finished
# [EXTRACT] Row 235 finished
# [EXTRACT] Row 236 finished
# [EXTRACT] Row 237 finished
# [EXTRACT] Row 238 finished
# [EXTRACT] Row 239 finished
# [EXTRACT] Row 240 finished
# [EXTRACT] Row 241 finished
# [EXTRACT] Row 242 finished
# [EXTRACT] Row 243 finished
# [EXTRACT] Row 244 finished
# [EXTRACT] Row 245 finished
# [EXTRACT] Row 246 finished
# [EXTRACT] Row 247 finished
# [EXTRACT] Row 248 finished
# [EXTRACT] Row 249 finished
# [EXTRACT] Row 250 finished
# [EXTRACT] Row 251 finished
# [EXTRACT] Row 252 finished
# [EXTRACT] Row 253 finished
# [EXTRACT] Row 254 finished
# [EXTRACT] Row 255 finished
# [EXTRACT] Row 256 finished
# [EXTRACT] Row 257 finished
# [EXTRACT] Row 258 finished
# [EXTRACT] Row 259 finished
# [EXTRACT] Row 260 finished
# [EXTRACT] Row 261 finished
# [EXTRACT] Row 262 finished
# [EXTRACT] Row 263 finished
# [EXTRACT] Row 264 finished
# [EXTRACT] Row 265 finished
# [EXTRACT] Row 266 finished
# [EXTRACT] Row 267 finished
# [EXTRACT] Row 268 finished
# [EXTRACT] Row 269 finished
# [EXTRACT] Row 270 finished
# [EXTRACT] Row 271 finished
# [EXTRACT] Row 272 finished
# [EXTRACT] Row 273 finished
# [EXTRACT] Row 274 finished
# [EXTRACT] Row 275 finished
# [EXTRACT] Row 276 finished
# [EXTRACT] Row 277 finished
# [EXTRACT] Row 278 finished
# [EXTRACT] Row 279 finished
# [EXTRACT] Row 280 finished
# [EXTRACT] Row 281 finished
# [EXTRACT] Row 282 finished
# [EXTRACT] Row 283 finished
# [EXTRACT] Row 284 finished
# [EXTRACT] Row 285 finished
# [EXTRACT] Row 286 finished
# [EXTRACT] Row 287 finished
# [EXTRACT] Row 288 finished
# [EXTRACT] Row 289 finished
# [EXTRACT] Row 290 finished
# [EXTRACT] Row 291 finished
# [EXTRACT] Row 292 finished
# [EXTRACT] Row 293 finished
# [EXTRACT] Row 294 finished
# [EXTRACT] Row 295 finished
# [EXTRACT] Row 296 finished
# [EXTRACT] Row 297 finished
# [EXTRACT] Row 298 finished
# [EXTRACT] Row 299 finished
# [EXTRACT] Row 300 finished
# [EXTRACT] Row 301 finished
# [EXTRACT] Row 302 finished
# (303, 7)
# (303, 1)
# WRITING X
# WRITING y
# Done.

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
import random
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, Adagrad
from data_augmentation import avg_combinations

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Data Augmentation**
#
# Augmentation is a crucial element of preparing a dataset for training. Although relatively simple, it helps the neural network recognize patterns with limited data.

# %%
def avg_combinations(x, n_augmentations):
  n_features = len(x[0])
  avg_col = [np.mean(x[:, i]) for i in range(n_features)]

  for i in range(n_augmentations):
    selected_case = x[int(random.randint(0, len(x)-1)), :]
    
    for j in range(random.randint(0, n_features)):
      removed_feature_index = random.randint(0, n_features-1)
      selected_case[removed_feature_index] = avg_col[removed_feature_index]
    
    np.append(x, selected_case)
  
  return x

# %% [markdown]
# **Unpacking Files**
#
# This code snippet unpacks the files created in ```
# data_extraction.py```. Furthermore, it splits the data into its classifcations, an action necessary for the next step of augmentation.

# %%
def open_files():
  # extracts the data from the two .pkl files
  X = []
  y = []

  with open('X.pkl', 'rb') as r:
    X = pickle.load(r)

  with open('y.pkl', 'rb') as r:
    y = pickle.load(r)
  
  y = [p[0] for p in y]

  X_0 = []
  X_1 = []
  for i in range(len(X)):
    if y[i] == 0:
        X_0.append(X[i])
    else:
        X_1.append(X[i])

  X_0 = np.array(X_0)
  X_1 = np.array(X_1)
  return X_0, X_1

X_0, X_1 = open_files()

# %%
X_0 = avg_combinations(X_0, 200)
X_1 = avg_combinations(X_1, 200)

y_0 = np.array([[0] for x in range(len(X_0))])
y_1 = np.array([[1] for x in range(len(X_1))])

# %%
X = np.concatenate((X_0, X_1))
y = np.concatenate((y_0, y_1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# **Model Creation and Training**
#
# By far the most important part, this code snippet contains the actual design for the neural network, incuding the number of hidden layers, the number of neurons for each, and their activiation layers. It also trains the model with the data prepared earlier for 100 epochs.

# %%
prediction_model = Sequential([
  Dense(7, input_dim=7, activation='relu'),
  Dense(64, activation='relu'),
  Dense(64, activation='relu'),
  Dense(80, activation='relu'),
  Dense(80, activation='relu'),
  Dense(80, activation='relu'),
  Dense(80, activation='relu'),
  Dense(16, activation='relu'),
  Dropout(0.5),
  Dense(1, activation='sigmoid')                            
]);

prediction_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

prediction_model.fit(X_train, y_train, batch_size=3, epochs=100)
# Out:
# Epoch 1/100
# 71/71 [==============================] - 1s 2ms/step - loss: 0.6411 - accuracy: 0.6975
# Epoch 2/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8930
# Epoch 3/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8815
# Epoch 4/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9293
# Epoch 5/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2478 - accuracy: 0.9211
# Epoch 6/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2361 - accuracy: 0.9340
# Epoch 7/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.9387
# Epoch 8/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9356
# Epoch 9/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1982 - accuracy: 0.9247
# Epoch 10/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.9459
# Epoch 11/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1927 - accuracy: 0.9176
# Epoch 12/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3097 - accuracy: 0.9067
# Epoch 13/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1614 - accuracy: 0.9619
# Epoch 14/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9446
# Epoch 15/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.9119
# Epoch 16/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9215
# Epoch 17/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9453
# Epoch 18/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3002 - accuracy: 0.8932
# Epoch 75/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9290
# Epoch 76/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9513
# Epoch 77/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1889 - accuracy: 0.9561
# Epoch 78/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1717 - accuracy: 0.9113
# Epoch 79/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.9238
# Epoch 80/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1523 - accuracy: 0.9262
# Epoch 81/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9233
# Epoch 82/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.2040 - accuracy: 0.9258
# Epoch 83/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9377
# Epoch 84/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9260
# Epoch 85/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9594
# Epoch 86/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9535
# Epoch 87/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1781 - accuracy: 0.9522
# Epoch 88/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1642 - accuracy: 0.9445
# Epoch 89/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.9352
# Epoch 90/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9212
# Epoch 91/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1586 - accuracy: 0.8840
# Epoch 92/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9387
# Epoch 93/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1219 - accuracy: 0.9287
# Epoch 94/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9252
# Epoch 95/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9733
# Epoch 96/100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9306
# Epoch 97/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1628 - accuracy: 0.9089
# Epoch 98/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1837 - accuracy: 0.9125
# Epoch 99/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9347
# Epoch 100/100
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.9259

# %% [markdown]
# **Testing the Model**
#
# Now, we test the model against samples that were not used for the training.

# %%
results = prediction_model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9780

# %%
prediction_model.save('model_9780.h5')
